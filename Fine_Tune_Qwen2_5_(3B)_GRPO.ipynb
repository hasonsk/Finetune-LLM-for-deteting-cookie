# %% [markdown]
# <a href="https://colab.research.google.com/github/hasonsk/Finetune-LLM-for-deteting-cookie/blob/main/Fine_Tune_Qwen2_5_(3B)_GRPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Read our **[Qwen3 Guide](https://docs.unsloth.ai/basics/qwen3-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft "trl==0.15.2" triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Qwen 2.5 3B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel, is_bfloat16_supported
import torch
max_seq_length = 2048 # Can increase for longer reasoning traces
lora_rank = 64 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "Qwen/Qwen2.5-3B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.5, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 05-05 11:32:41 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 05-05 11:32:41 [__init__.py:239] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.4.7: Fast Qwen2 patching. Transformers: 4.51.3. vLLM: 0.8.5.post1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit with actual GPU utilization = 49.53%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.74 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 192.
# Unsloth: vLLM's KV Cache can use up to 4.88 GB. Also swap space = 2 GB.
# WARNING 05-05 11:32:51 [config.py:2972] Casting torch.bfloat16 to torch.float16.
# INFO 05-05 11:33:06 [config.py:717] This model supports multiple tasks: {'generate', 'embed', 'score', 'classify', 'reward'}. Defaulting to 'generate'.
# WARNING 05-05 11:33:06 [arg_utils.py:1658] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# Unsloth: vLLM Bitsandbytes config using kwargs = {'load_in_8bit': False, 'load_in_4bit': True, 'bnb_4bit_compute_dtype': 'float16', 'bnb_4bit_quant_storage': 'uint8', 'bnb_4bit_quant_type': 'nf4', 'bnb_4bit_use_double_quant': True, 'llm_int8_enable_fp32_cpu_offload': False, 'llm_int8_has_fp16_weight': False, 'llm_int8_skip_modules': ['lm_head', 'multi_modal_projector', 'merger', 'modality_projection', 'model.layers.2.mlp', 'model.layers.3.mlp', 'model.layers.30.mlp'], 'llm_int8_threshold': 6.0}
# INFO 05-05 11:33:06 [llm_engine.py:240] Initializing a V0 LLM engine (v0.8.5.post1) with config: model='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', speculative_config=None, tokenizer='unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.BITSANDBYTES, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=bitsandbytes, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda:0, decoding_config=DecodingConfig(guided_decoding_backend='auto', reasoning_backend=None), observability_config=ObservabilityConfig(show_hidden_metrics=False, otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=False, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"level":0,"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":192}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# INFO 05-05 11:33:11 [cuda.py:240] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 05-05 11:33:11 [cuda.py:289] Using XFormers backend.
# INFO 05-05 11:33:11 [parallel_state.py:1004] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0
# INFO 05-05 11:33:11 [model_runner.py:1108] Starting to load model unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit...
# INFO 05-05 11:33:12 [loader.py:1187] Loading weights with BitsAndBytes quantization. May take a while ...
# INFO 05-05 11:33:12 [weight_utils.py:265] Using model weights format ['*.safetensors']
# model.safetensors:   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# INFO 05-05 11:34:52 [weight_utils.py:281] Time spent downloading weights for unsloth/qwen2.5-3b-instruct-unsloth-bnb-4bit: 99.612658 seconds
# INFO 05-05 11:34:52 [weight_utils.py:315] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 05-05 11:34:59 [punica_selector.py:18] Using PunicaWrapperGPU.
# INFO 05-05 11:35:00 [model_runner.py:1140] Model loading took 2.4392 GiB and 107.758285 seconds
# INFO 05-05 11:35:11 [worker.py:287] Memory profiling takes 10.56 seconds
# INFO 05-05 11:35:11 [worker.py:287] the current vLLM instance can use total_gpu_memory (14.74GiB) x gpu_memory_utilization (0.50) = 7.30GiB
# INFO 05-05 11:35:11 [worker.py:287] model weights take 2.44GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 1.05GiB; the rest of the memory reserved for KV Cache is 3.78GiB.
# INFO 05-05 11:35:11 [executor_base.py:112] # cuda blocks: 6887, # CPU blocks: 3640
# INFO 05-05 11:35:11 [executor_base.py:117] Maximum concurrency for 2048 tokens per request: 53.80x
# INFO 05-05 11:35:14 [model_runner.py:1450] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/27 [00:00<?, ?it/s]
# INFO 05-05 11:36:09 [model_runner.py:1592] Graph capturing finished in 56 secs, took 0.56 GiB
# INFO 05-05 11:36:09 [llm_engine.py:437] init engine (profile, create kv cache, warmup model) took 69.57 seconds
# tokenizer_config.json:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Unsloth 2025.4.7 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
import os, wandb
from huggingface_hub import login

os.environ["WANDB_API_KEY"] = "810a489e4029d94651a3868c08a49812cc1e4cc7"
os.environ["HUGGINGFACE_API_KEY"] = "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"

# %%
hf_token = os.environ["HUGGINGFACE_API_KEY"]
login(hf_token)

secret_key = os.environ["WANDB_API_KEY"]
wandb.login(key=secret_key)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sonhh2003 (sonhh2003-hanoi-university-of-science-and-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import Dataset, load_dataset

SYSTEM_PROMPT = """
ROLE: You are a cookie policy analysis expert.
Your task is to read a cookie policy text and extract detailed information about each cookie mentioned in that policy.
RESPONSE Format: If no cookies are specifically described, return []. Otherwise, return the result as a JSON array following structure:
  [
    {
      "cookie_name": "cookie_name",
      "declared_purpose": "declared_purpose",
      "declared_retention": "declared_retention",
      "declared_third_parties": ["declared_third_parties"],
      "declared_description": "declared_description"
    }
  ]

Specific Requirements:
  Read and Analyze the Text: Carefully read the entire content of the cookie policy to understand the types of cookies used, their purposes, storage duration, detailed descriptions, and information about the owner (first party or third party).
  Identify Described Cookies: Search for sections, paragraphs, or text that describe specific cookies. Each cookie will usually have its own entry or be listed in a list. If not found cookies, return [] and dont say anymore.

  Extract Detailed Information for Each Cookie: For each identified cookie, carefully extract the following information from the policy:
    +) "cookie_name": Find the technical name or descriptive name of the cookie exactly as it is mentioned in the policy.
    +) "declared_purpose": A detailed description of the cookie's purpose. With the following options:
        +) Strictly Necessary: Cookies essential for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation).
        +) Functionality: Cookies that help personalize the user experience and provide additional features (e.g., remembering language preferences, page layouts).
        +) Analytical: Cookies used to collect data and understand user behavior on the website (e.g., number of visits, most viewed pages).
        +) Targeting/Advertising/Marketing: Cookies used to display personalized advertisements based on user behavior or interests.
        +) Performance: Cookies that help improve the technical performance of the website (e.g., optimizing page loading, content distribution).
        +) Social Sharing: Cookies that enable sharing content from the website to social media platforms.
        +) Null if the policy does not provide any specific information about the purpose of this cookie.
    +) "declared_retention": Find information about the duration this cookie will be stored on the user's device (e.g., "6 months", "24 hours", "Session", "Persistent", "1 minute", "Until deleted"). Record this information as accurately as possible according to the original text.
    +) "declared_third_parties": An array of third parties involved in the use of this cookie (if any). ["First Party"] indicates a first-party cookie set by the website itself.
    +) "declared_description": The content taken directly from the text, without fabrication, using exactly what they have described.
"""

def preprocess(example):
    if example['english_content']:
        content = f"Cookie policy: {example['english_content']}\nTable: {example['english_table']}"
    elif example['english_table']:
        content = f"Table: {example['english_table']}"
    else:
        content = f"Content: {example['english_table']}"

    prompt = [
        {'role': 'system', 'content': SYSTEM_PROMPT},
        {'role': 'user', 'content': content}
    ]

    return {
        'prompt': prompt,
        'answer': example['label']
        # 'answer': '[]'
    }

dataset = load_dataset("sonhask/detect-cookie-with-label")
dataset = dataset['train'].map(preprocess)
# Out:
# README.md:   0%|          | 0.00/640 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/48.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/12441 [00:00<?, ? examples/s]
# Map:   0%|          | 0/12441 [00:00<?, ? examples/s]

# %%
def compute_token_length(example):
    length =  (
              len(example['answer']) +
               len(example["prompt"][0]['content']) + len(example["prompt"][1]['content']))*0.331 + 50
    return length

dataset = dataset.filter(lambda example: compute_token_length(example) <= 2048)
len(dataset)
# Out:
# Filter:   0%|          | 0/12441 [00:00<?, ? examples/s]
# 7254

# %%
def thong_ke(dataset):
    empty_label_count = 0
    non_empty_label_count = 0

    for i in dataset:
        if i['answer'] == '[]':
            empty_label_count += 1
        else:
            non_empty_label_count += 1

    print("#[]: ", empty_label_count)
    print("#Has cookies: ", non_empty_label_count)

thong_ke(dataset)
# Out:
# #[]:  6667
# #Has cookies:  587

# %%
# 2. remove every column except the one GRPOTrainer expects:
keep = ["prompt", "answer"]
to_remove = [c for c in dataset.column_names if c not in keep]
dataset = dataset.remove_columns(to_remove)

# 3. now dataset.features == ['prompt']
print(dataset.features)
# Out:
# {'prompt': [{'content': Value(dtype='string', id=None), 'role': Value(dtype='string', id=None)}], 'answer': Value(dtype='string', id=None)}

# %%
import jsonschema
import json
from jsonschema import validate, ValidationError
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from itertools import zip_longest

embedder = SentenceTransformer('all-MiniLM-L6-v2')  # small, fast

schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "cookie_name": {"type": "string"},
            "declared_purpose": {"type": ["string", "null"]},
            "declared_retention": {"type": ["string", "null"]},
            "declared_third_parties": {"type": "array"},
            "declared_description": {"type": ["string", "null"]}
        },
        "required": ["cookie_name"]
    }
}

def strict_format_reward_func(completions, **kwargs):
    rewards = []
    for completion in completions:
        try:
            response = json.loads(completion[0]['content'])
            validate(instance=response, schema=schema)
            rewards.append(1.0)
        except (json.JSONDecodeError, ValidationError):
            rewards.append(-1.0)
    return rewards

# Hàm này kiểm tra xem đầu ra có thể được phân tích cú pháp thành JSON hợp lệ hay không, mà không cần xác thực theo schema.
def soft_format_reward_func(completions, **kwargs):
    rewards = []
    for completion in completions:
        try:
            json.loads(completion[0]['content'])
            rewards.append(0.5)
        except json.JSONDecodeError:
            rewards.append(-0.5)
    return rewards


def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    rewards = []
    for completion, answer in zip(completions, answer):
        try:
            response = json.loads(completion[0]['content'])
            ground_truth = json.loads(answer)
            validate(instance=response, schema=schema)
            correct_items = sum(1 for r_item in response if r_item in ground_truth)
            total_items = len(ground_truth)
            score = correct_items / total_items if total_items > 0 else 0.0
            rewards.append(score)
        except (json.JSONDecodeError, ValidationError):
            rewards.append(-1.0)
    return rewards

# Hàm này đánh giá mức độ đầy đủ của các trường trong mỗi mục của đầu ra, tính điểm dựa trên tỷ lệ các trường không rỗng.
def field_completeness_reward_func(completions, **kwargs) -> list[float]:
    rewards = []
    for comp in completions:
        try:
            arr = json.loads(comp[0]["content"])
            total = len(arr) * 5
            filled = 0
            for item in arr:
                for v in [
                    item.get("cookie_name"),
                    item.get("declared_purpose"),
                    item.get("declared_retention"),
                    item.get("declared_third_parties"),
                    item.get("declared_description"),
                ]:
                    if v not in (None, "", []):
                        filled += 1
            rewards.append(filled / total if total else 0.0)
        except Exception:
            rewards.append(-1.0)
    return rewards

# FIELD-LEVEL REWARD
def field_level_reward(prompts, completions, answer, **kwargs) -> list[float]:
    required_fields = [
        "cookie_name",
        "declared_purpose",
        "declared_retention",
        "declared_third_parties",
        "declared_description",
    ]
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]
    print('*'*20, f"Question:\n{question}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}")

    rewards = []
    for comp, answer in zip(completions, answer):
        print("Len of comp: ", len(comp))
        print("Answer: ", answer)
        print("---> PREDICT: ", comp[0]["content"])
        try:
            pred = json.loads(comp[0]["content"])
            ground_truth = json.loads(answer)
        except Exception:
            rewards.append(-1.0)
            continue

        if not isinstance(pred, list):
            rewards.append(0.0)
            continue

        score = 0.0
        matched = 0
        for p_item, g_item in zip_longest(pred, ground_truth, fillvalue={}):
            if not isinstance(p_item, dict):
                score -= 1.0
                matched += 1
                continue

            match = 0
            for f in required_fields:
                if p_item.get(f) == g_item.get(f):
                    match += 1
            score += match / len(required_fields)
            matched += 1

        rewards.append(score / matched if matched else 0.0)
    return rewards

# JACCARD ON THIRD PARTIES
def jaccard_third_party_reward(prompts, completions, answer, **kwargs) -> list[float]:
    rewards = []

    for comp, answer in zip(completions, answer):
        try:
            pred = json.loads(comp[0]["content"])
            ground_truth = json.loads(answer)
        except Exception:
            rewards.append(-3.0)
            continue

        if not isinstance(pred, list):
            rewards.append(-3.0)
            continue

        scores = []
        for p_item, g_item in zip_longest(pred, ground_truth, fillvalue={}):
            if isinstance(p_item, dict):
                set_p = set(p_item.get("declared_third_parties", []) or [])
                set_g = set(g_item.get("declared_third_parties", []))
                inter = len(set_p & set_g)
                union = len(set_p | set_g)
                scores.append(inter / union if union > 0 else 0.0)

            else:
                scores.append(-1.0)
                continue
        rewards.append(sum(scores) / len(scores) if scores else 0.0)
    return rewards

def semantic_description_reward(prompts, completions, answer, **kwargs) -> list[float]:
    rewards = []
    for comp, answer in zip(completions, answer):
        try:
            pred = json.loads(comp[0]["content"])
            ground_truth = json.loads(answer)
        except:
            rewards.append(-1.0)
            continue

        sims = []
        for p_item, g_item in zip(pred, ground_truth):
            if p_item is None:
                sims.append(-1.0)
                continue
            elif isinstance(p_item, dict):
                desc_p = str(p_item.get("declared_description", ""))
                desc_g = g_item.get("declared_description", "")
                emb = embedder.encode([desc_p, desc_g])
                sims.append(float(cosine_similarity([emb[0]], [emb[1]])[0][0]))
            else:
                sims.append(-1.0)
                continue
        rewards.append(sum(sims) / len(sims) if sims else 0.0)
    return rewards

# def composite_reward(prompts, completions, answers, **kwargs):
#     r1 = strict_format_reward_func(completions, **kwargs)
#     r2 = soft_format_reward_func(completions, **kwargs)
#     r3 = field_completeness_reward_func(completions, **kwargs)
#     r4 = field_level_reward(prompts, completions, answers, **kwargs)
#     r5 = jaccard_third_party_reward(prompts, completions, answers, **kwargs)
#     r6 = semantic_description_reward(prompts, completions, answers, **kwargs)
#     # weights
#     w = [1.0, 0.5, 1.0, 2.0, 1.0, 1.0]
#     return [
#         w[0]*a + w[1]*b + w[2]*c + w[3]*d + w[4]*e + w[5]*f
#         for a,b,c,d,e,f in zip(r1,r2,r3,r4,r5,r6)
#     ]
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
run = wandb.init(
    project="Fine-tune Llama 3_1 8B GRPO",
)
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250505_114024-umu7qd38</code>
# Syncing run <strong><a href='https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO/runs/umu7qd38' target="_blank">sith-xwing-4</a></strong> to <a href='https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO' target="_blank">https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO</a>
#  View run at <a href='https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO/runs/umu7qd38' target="_blank">https://wandb.ai/sonhh2003-hanoi-university-of-science-and-technology/Fine-tune%20Llama%203_1%208B%20GRPO/runs/umu7qd38</a>

# %%
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    use_vllm = True, # use vLLM for fast inference!
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_8bit",
    logging_steps = 1,
    bf16 = is_bfloat16_supported(),
    fp16 = not is_bfloat16_supported(),
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 2, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = 2048,
    # max_completion_length = 200,
    num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 600,
    save_steps = 50,
    max_grad_norm = 0.1,
    report_to = "wandb", # Can use Weights & Biases
    output_dir = "/content/drive/MyDrive/Qwen2.5_(3B)-GRPO",
)

# %% [markdown]
# And let's run the trainer! If you
#
# 1.   List item
# 2.   List item
#
# scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        strict_format_reward_func,
        soft_format_reward_func,
        correctness_reward_func,
        field_completeness_reward_func,
        field_level_reward,
        jaccard_third_party_reward,
        semantic_description_reward,
    ],
    args = training_args,
    train_dataset = dataset,
)

# trainer.train()
trainer.train(resume_from_checkpoint=True)
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 7,254 | Num Epochs = 1 | Total steps = 300
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 119,734,272/3,000,000,000 (3.99% trained)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# ******************** Question:
# Cookie policy: EN
# Cookies policy
# We are MACEK.LEGAL, a law firm that provides a full legal service for your business, which is why we operate this website. The administrator of your personal data is MACEK.LEGAL s.r.o., law firm, ID number: 19543166, with registered office at Haštalská 1072/6, 110 00 Prague 1. You can also find out more information about the processing of your personal data here.
# Cookies are text files containing a small amount of information that are downloaded to your mobile phone, computer or other device when you visit our website. On each subsequent visit to our website, cookies are then sent back to the original website or to another page that recognizes cookies. Simply put - the website uses cookies to store information about your visit to the website.
# Our website uses different categories of cookies for different purposes. Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies. We can process essential cookies without your consent. We can process all other cookies only with your consent, which you can revoke (reject) at any time in the cookie settings. However, withdrawing or not granting your consent may affect your browsing of our website.
#
# Table: []
# Answer:
# [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": null,
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies."
#   }
# ]
# Response:
# [
#     {
#       "cookie_name": "Necessary Cookies",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Necessary cookies are necessary for the basic functionality of the website. We can process essential cookies without your consent."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": null,
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies."
#   }
# ]
# ---> PREDICT:  [
#     {
#       "cookie_name": "Necessary Cookies",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Necessary cookies are necessary for the basic functionality of the website. We can process essential cookies without your consent."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": null,
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies."
#   }
# ]
# ---> PREDICT:  []
# According to the provided cookie policy, there are no specific cookies mentioned or described. Therefore, the result is an empty array [].
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": null,
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies."
#   }
# ]
# ---> PREDICT:  [
#     {
#         "cookie_name": "essential_cookies",
#         "declared_purpose": "Strictly Necessary",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "The website uses cookies to store information about your visit to the website. Simply put - the website uses cookies to store information about your visit to the website."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": null,
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "Necessary cookies are necessary for the basic functionality of the website. So that our website can fulfill its basic function, we cannot do without these cookies."
#   }
# ]
# ---> PREDICT:  [
#     {
#       "cookie_name": "Session cookies or similar technology",
#       "declared_purpose": "These cookies are required for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation).",
#       "declared_retention": "Session",
#       "declared_third_parties": [],
#       "declared_description": "Necessary cookies are necessary for the basic functionality of the website. Without them, we cannot do the following: managing login sessions, shopping cart functionality, secure navigation. We can process essential cookies without your consent."
#     }
# ]
# ******************** Question:
# Cookie policy: Cookies
# How we use Cookies
# We may use “cookies” on our website. Cookies are data files which store information on your hard drive or browser that means that our website can recognise that you have visited our website before. They make it easier for you to maintain your preferences on this website. You can, should you choose, disable the cookies from your browser and delete all cookies currently stored on your computer. On Microsoft Internet Explorer, this can be done by selecting ‘Tools/Internet Options’ and reviewing your privacy settings or selecting ‘delete cookies’. You can find out how to do this for your particular browser by clicking ‘help’ on your browser's menu or by visiting www.allaboutcookies.org/manage-cookies/index.html . However, many of our website features will not function if you disable cookies.
# Google Analytics is a system used by many website to record information about who visits a website. Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "cookie name for Google Analytics",
#       "declared_purpose": "Performance, Analytical",
#       "declared_retention": "1 day to 2 years",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "cookie name for Google Analytics",
#       "declared_purpose": "Performance, Analytical",
#       "declared_retention": "1 day to 2 years",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Google Analytics",
#         "declared_purpose": "analytical, null",
#         "declared_retention": "1 day to 2 years",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Google Analytics cookies",
#         "declared_purpose": "Mainly to differentiate between first time visitors to a website and repeat visitors",
#         "declared_retention": "1 day to 2 years",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Google Analytics cookies",
#       "declared_purpose": "These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors",
#       "declared_retention": "1 day to 2 years",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Google set five different cookies with expiry dates ranging from 1 day to 2 years. These cookies are used mainly to differentiate between first time visitors to a website and repeat visitors. They do not contain any personally identifiable information. You can find out more about how Google use cookies at www.google.com/intl/en/analytics/privacyoverview.html (English only)"
#     }
# ]
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 3:08:44, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / strict_format_reward_func</th>
#       <th>rewards / soft_format_reward_func</th>
#       <th>rewards / correctness_reward_func</th>
#       <th>rewards / field_completeness_reward_func</th>
#       <th>rewards / field_level_reward</th>
#       <th>rewards / jaccard_third_party_reward</th>
#       <th>rewards / semantic_description_reward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>1.745602</td>
#       <td>3.182096</td>
#       <td>111.125000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>0.375000</td>
#       <td>-0.125000</td>
#       <td>0.725000</td>
#       <td>-0.025000</td>
#       <td>-0.125000</td>
#       <td>0.170602</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>2.125000</td>
#       <td>3.584609</td>
#       <td>163.625000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>0.375000</td>
#       <td>0.062500</td>
#       <td>0.662500</td>
#       <td>0.212500</td>
#       <td>-0.187500</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-3.125000</td>
#       <td>6.213381</td>
#       <td>54.875000</td>
#       <td>0.000016</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>-0.175000</td>
#       <td>-0.450000</td>
#       <td>-1.500000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-2.175000</td>
#       <td>2.650000</td>
#       <td>27.875000</td>
#       <td>0.000023</td>
#       <td>0.250000</td>
#       <td>0.125000</td>
#       <td>-0.375000</td>
#       <td>-0.300000</td>
#       <td>-0.375000</td>
#       <td>-1.125000</td>
#       <td>-0.375000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-4.750000</td>
#       <td>2.500000</td>
#       <td>131.625000</td>
#       <td>0.000229</td>
#       <td>-0.250000</td>
#       <td>-0.125000</td>
#       <td>-0.625000</td>
#       <td>-0.625000</td>
#       <td>-0.625000</td>
#       <td>-1.875000</td>
#       <td>-0.625000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.447845</td>
#       <td>2.865048</td>
#       <td>121.625000</td>
#       <td>0.000007</td>
#       <td>0.750000</td>
#       <td>0.375000</td>
#       <td>-0.125000</td>
#       <td>0.662500</td>
#       <td>-0.037500</td>
#       <td>-0.375000</td>
#       <td>0.197845</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-0.375000</td>
#       <td>3.037954</td>
#       <td>109.000000</td>
#       <td>0.000029</td>
#       <td>0.500000</td>
#       <td>0.250000</td>
#       <td>-0.250000</td>
#       <td>0.375000</td>
#       <td>-0.250000</td>
#       <td>-0.750000</td>
#       <td>-0.250000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>-1.750000</td>
#       <td>5.783562</td>
#       <td>118.000000</td>
#       <td>0.000010</td>
#       <td>0.250000</td>
#       <td>0.125000</td>
#       <td>-0.375000</td>
#       <td>0.125000</td>
#       <td>-0.375000</td>
#       <td>-1.125000</td>
#       <td>-0.375000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>1.788675</td>
#       <td>19.875000</td>
#       <td>0.000168</td>
#       <td>0.750000</td>
#       <td>0.500000</td>
#       <td>-0.125000</td>
#       <td>0.125000</td>
#       <td>-0.125000</td>
#       <td>-0.125000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>-3.350000</td>
#       <td>0.238048</td>
#       <td>160.500000</td>
#       <td>0.000006</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>-0.400000</td>
#       <td>-0.450000</td>
#       <td>-1.500000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-6.500000</td>
#       <td>0.000000</td>
#       <td>15.875000</td>
#       <td>0.000058</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>-1.000000</td>
#       <td>-1.000000</td>
#       <td>-2.000000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>-1.750000</td>
#       <td>5.818761</td>
#       <td>85.625000</td>
#       <td>0.000015</td>
#       <td>0.250000</td>
#       <td>0.125000</td>
#       <td>-0.375000</td>
#       <td>0.125000</td>
#       <td>-0.375000</td>
#       <td>-1.125000</td>
#       <td>-0.375000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>-2.000000</td>
#       <td>4.000000</td>
#       <td>10.750000</td>
#       <td>0.000118</td>
#       <td>0.000000</td>
#       <td>0.375000</td>
#       <td>-0.500000</td>
#       <td>-0.500000</td>
#       <td>-0.500000</td>
#       <td>-0.750000</td>
#       <td>-0.125000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-3.500000</td>
#       <td>0.000000</td>
#       <td>33.875000</td>
#       <td>0.000246</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>-0.500000</td>
#       <td>-0.500000</td>
#       <td>-1.500000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-3.025000</td>
#       <td>5.450000</td>
#       <td>104.625000</td>
#       <td>0.000022</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>-0.025000</td>
#       <td>-0.500000</td>
#       <td>-1.500000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>-3.803684</td>
#       <td>6.585908</td>
#       <td>156.000000</td>
#       <td>0.000173</td>
#       <td>-0.250000</td>
#       <td>-0.125000</td>
#       <td>-0.625000</td>
#       <td>-0.250000</td>
#       <td>-0.525000</td>
#       <td>-1.625000</td>
#       <td>-0.403684</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>-0.625000</td>
#       <td>5.271127</td>
#       <td>54.125000</td>
#       <td>0.000388</td>
#       <td>0.500000</td>
#       <td>0.250000</td>
#       <td>-0.250000</td>
#       <td>0.125000</td>
#       <td>-0.250000</td>
#       <td>-0.750000</td>
#       <td>-0.250000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-2.125000</td>
#       <td>5.487015</td>
#       <td>46.750000</td>
#       <td>0.001074</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>-1.125000</td>
#       <td>-0.375000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>-0.700000</td>
#       <td>3.234293</td>
#       <td>51.875000</td>
#       <td>0.000570</td>
#       <td>0.500000</td>
#       <td>0.250000</td>
#       <td>-0.250000</td>
#       <td>0.050000</td>
#       <td>-0.250000</td>
#       <td>-0.750000</td>
#       <td>-0.250000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000200</td>
#       <td>-3.250000</td>
#       <td>4.094959</td>
#       <td>21.250000</td>
#       <td>0.005588</td>
#       <td>-0.250000</td>
#       <td>0.250000</td>
#       <td>-0.625000</td>
#       <td>-0.625000</td>
#       <td>-0.625000</td>
#       <td>-1.125000</td>
#       <td>-0.250000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>-3.050000</td>
#       <td>5.433740</td>
#       <td>157.375000</td>
#       <td>0.001234</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>-0.050000</td>
#       <td>-0.500000</td>
#       <td>-1.500000</td>
#       <td>-0.500000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>1.075000</td>
#       <td>2.783740</td>
#       <td>122.875000</td>
#       <td>0.000148</td>
#       <td>0.750000</td>
#       <td>0.375000</td>
#       <td>-0.125000</td>
#       <td>0.700000</td>
#       <
# Streaming output truncated to the last 5000 lines.
# ---> PREDICT:  [
#     {
#         "cookie_name": "N/A",
#         "declared_purpose": "Saving login details",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["N/A"],
#         "declared_description": "A number of our pages use cookies to remember saving login details. These cookies are not strictly necessary but can provide a better browsing experience."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "_ga",
#       "declared_purpose": "for statistic purposes",
#       "declared_retention": "Persistent",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "A cookie used to collect data and understand user behavior on the website."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "session cookie",
#         "declared_purpose": "for statistic purposes, saving login details",
#         "declared_retention": "Session",
#         "declared_third_parties": ["BORuM"],
#         "declared_description": "A cookie for statistic purposes and saving login details."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Understood",
#         "declared_purpose": "saving login details",
#         "declared_retention": "Session",
#         "declared_third_parties": ["BORuM"],
#         "declared_description": "A number of our pages use cookies to remember saving login details."
#     }
# ]
# ******************** Question:
# Cookie policy: Try our repricing software today.
# Automatic price adjustment in minutes!
# Thank you! Your submission has been received!
# Oops! Something went wrong while submitting the form.
# Fair compensation models
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "Unnamed Cookie",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Unnamed Cookie",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "UNSPECIFIED",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "The cookie has not been described in the provided text, thus no details are available."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Cookie",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Cookie",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This cookie is not related to any specific purpose, duration, or third parties. It is simply a generic cookie set by the website."
#     }
# ]
# ******************** Question:
# Cookie policy: Rue Léon Blum - Building 5, 62750 Loos-En-Gohelle
# Tel: +33 (0) 321 28 17 28
# www.chainedesterrils.eu
# Cookie management policy
# In accordance with article 6, al. 1, let. a and f of the General Data Protection Regulation (or GDPR) of April 27, 2016, three types of cookies are used when browsing this website:
# So-called “necessary” cookies: they are essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months.
# “Functional” cookies linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above.
# Finally, “performance” cookies collect non-anonymized statistical data. Their shelf life is a maximum of 26 months.
# At any time, you can change your mind regarding the cookies you allow on your device via the cookie manager at the bottom of the page. You can also clear cookies by deleting your browser's browsing history.
# Articles 15 to 22 of the GDPR give you the right to:
# request details of personal data collected;
# the destination of the processing of the above-mentioned information if processing is planned;
# request rectification or erasure of personal data (“right to be forgotten”);
# request a limitation in the processing of personal data;
# object to the processing of personal data concerning you.
# If you consider that your rights in relation to personal data and cookies have not been respected, we invite you to contact the data protection authority and file a complaint by following the following procedure: www.cnil.fr/fr/plaintes
#
# Table: []
# Answer:
# [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": "12 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#   },
#   {
#     "cookie_name": "Functional cookies",
#     "declared_purpose": "Functionality",
#     "declared_retention": "Depends on third parties",
#     "declared_third_parties": [
#       "Mapbox",
#       "YouTube",
#       "Soundcloud"
#     ],
#     "declared_description": "linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#   },
#   {
#     "cookie_name": "Performance cookies",
#     "declared_purpose": "Analytical",
#     "declared_retention": "26 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "collect non-anonymized statistical data. Their shelf life is a maximum of 26 months."
#   }
# ]
# Response:
# [
#     {
#       "cookie_name": "Necessary cookies",
#       "declared_purpose": "To calculate anonymized statistics, and to make the proper functioning of the site possible.",
#       "declared_retention": "12 months",
#       "declared_third_parties": ["Mapbox's built-in media players", "YouTube", "Soundcloud"],
#       "declared_description": "Functional cookies linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": "12 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#   },
#   {
#     "cookie_name": "Functional cookies",
#     "declared_purpose": "Functionality",
#     "declared_retention": "Depends on third parties",
#     "declared_third_parties": [
#       "Mapbox",
#       "YouTube",
#       "Soundcloud"
#     ],
#     "declared_description": "linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#   },
#   {
#     "cookie_name": "Performance cookies",
#     "declared_purpose": "Analytical",
#     "declared_retention": "26 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "collect non-anonymized statistical data. Their shelf life is a maximum of 26 months."
#   }
# ]
# ---> PREDICT:  [
#     {
#       "cookie_name": "Necessary cookies",
#       "declared_purpose": "To calculate anonymized statistics, and to make the proper functioning of the site possible.",
#       "declared_retention": "12 months",
#       "declared_third_parties": ["Mapbox's built-in media players", "YouTube", "Soundcloud"],
#       "declared_description": "Functional cookies linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": "12 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#   },
#   {
#     "cookie_name": "Functional cookies",
#     "declared_purpose": "Functionality",
#     "declared_retention": "Depends on third parties",
#     "declared_third_parties": [
#       "Mapbox",
#       "YouTube",
#       "Soundcloud"
#     ],
#     "declared_description": "linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#   },
#   {
#     "cookie_name": "Performance cookies",
#     "declared_purpose": "Analytical",
#     "declared_retention": "26 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "collect non-anonymized statistical data. Their shelf life is a maximum of 26 months."
#   }
# ]
# ---> PREDICT:  [
#     {
#       "cookie_name": "Session cookies",
#       "declared_purpose": "These cookies are essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months.",
#       "declared_retention": "12 months",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "So-called “necessary” cookies: they are essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": "12 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#   },
#   {
#     "cookie_name": "Functional cookies",
#     "declared_purpose": "Functionality",
#     "declared_retention": "Depends on third parties",
#     "declared_third_parties": [
#       "Mapbox",
#       "YouTube",
#       "Soundcloud"
#     ],
#     "declared_description": "linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#   },
#   {
#     "cookie_name": "Performance cookies",
#     "declared_purpose": "Analytical",
#     "declared_retention": "26 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "collect non-anonymized statistical data. Their shelf life is a maximum of 26 months."
#   }
# ]
# ---> PREDICT:  [
#     {
#         "cookie_name": "n/a",
#         "declared_purpose": "Strictly Necessary",
#         "declared_retention": "12 months",
#         "declared_third_parties": ["n/a"],
#         "declared_description": "They are essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#     }
# ]
# Len of comp:  1
# Answer:  [
#   {
#     "cookie_name": "Necessary cookies",
#     "declared_purpose": "Strictly Necessary",
#     "declared_retention": "12 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "essential for the proper functioning of the site when browsing by the visitor. They also make it possible to calculate anonymized statistics. They cannot be refused and are stored for 12 months."
#   },
#   {
#     "cookie_name": "Functional cookies",
#     "declared_purpose": "Functionality",
#     "declared_retention": "Depends on third parties",
#     "declared_third_parties": [
#       "Mapbox",
#       "YouTube",
#       "Soundcloud"
#     ],
#     "declared_description": "linked to third-party services such as Mapbox's built-in media players, YouTube and Soundcloud. The retention period of cookies and associated data as well as the treatment reserved depend on the third parties mentioned above."
#   },
#   {
#     "cookie_name": "Performance cookies",
#     "declared_purpose": "Analytical",
#     "declared_retention": "26 months",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": "collect non-anonymized statistical data. Their shelf life is a maximum of 26 months."
#   }
# ]
# ---> PREDICT:  [
#     {
#       "cookie_name": "Session cookies",
#       "declared_purpose": "they are essential for the proper functioning of the site when browsing by the visitor",
#       "declared_retention": "12 months",
#       "declared_third_parties": ["Mapbox", "YouTube", "Soundcloud"],
#       "declared_description": "These are cookies that make it possible to calculate anonymized statistics and are essential for the proper functioning of the site. They cannot be refused and are stored for 12 months."
#     }
# ]
# ******************** Question:
# Cookie policy: Games and Toys
# Set cookies
# Cookies are a technology that allows us to know how you use our site. With this information, we make it easier to use your account and show you advertising related to your interests.
# Learn more about cookies at Mercado Shops.
# Essential cookies
# They are used to recognize you when you log in, save your configuration preferences and protect your account. They cannot be disabled because they are necessary for the operation of our site.
# Analytical cookies
# They allow us to analyze your navigation on the site so that we can improve our services.
# traceability
# They allow us to understand your preferences to show you products and advertisements that are interesting to you.
# advertising
# They allow us to optimize some functions of our site.
# performance
# They allow us to keep our site running smoothly.
# functionality
# Charles Marketing Potosina del Centro
# Categories
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "traceability",
#       "declared_purpose": "They allow us to understand your preferences to show you products and advertisements that are interesting to you.",
#       "declared_retention": "Not specified",
#       "declared_third_parties": ["Charles Marketing Potosina del Centro"],
#       "declared_description": "They allow us to understand your preferences to show you products and advertisements that are interesting to you."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "traceability",
#       "declared_purpose": "They allow us to understand your preferences to show you products and advertisements that are interesting to you.",
#       "declared_retention": "Not specified",
#       "declared_third_parties": ["Charles Marketing Potosina del Centro"],
#       "declared_description": "They allow us to understand your preferences to show you products and advertisements that are interesting to you."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "traceability",
#       "declared_purpose": "They allow us to understand your preferences to show you products and advertisements that are interesting to you.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["Charles Marketing Potosina del Centro"],
#       "declared_description": "They allow us to understand your preferences to show you products and advertisements that are interesting to you."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "traceability",
#       "declared_purpose": "They allow us to understand your preferences to show you products and advertisements that are interesting to you.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["Charles Marketing Potosina del Centro"],
#       "declared_description": "They allow us to understand your preferences to show you products and advertisements that are interesting to you."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "traceability",
#       "declared_purpose": "To understand your preferences to show you products and advertisements that are interesting to you",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["Charles Marketing Potosina del Centro"],
#       "declared_description": "They allow us to understand your preferences to show you products and advertisements that are interesting to you."
#     }
# ]
# ******************** Question:
# Cookie policy: The EU region is not enabled for cookie-statement.
# Submit your article to the magazine!
# Participate in our society's magazine and send us your article to: magazinesac@cardioaragon.com
# Business Center Business Center C/ Eduardo Ibarra 6 50009 Zaragoza Spain
# +34 976 43 88 89
# info@cardioaragon.com
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "Not Provided",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "The EU region is not enabled for cookie-statement."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Not Provided",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "The EU region is not enabled for cookie-statement."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "The EU region is not enabled for cookie-statement."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Not Applicable",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "The EU region is not enabled for cookie-statement."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Placeholder",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "Null"
#     }
# ]
# ******************** Question:
# Cookie policy: Basket
# Product categories
# Beef Beef Stir Fries and Curries Boxing Day Breakfast BULK BUY DEALS Burns Night Products Chicken Stir Fries and Curries Christmas Seafood Selection Christmas Selection Christmas Trimmings Desserts Festive Birds Festive Roasts Frozen Fruit & Vegetables Galloway Christmas Hampers Gluten Free January Sale LARDER Lean Meat Meatballs OFFERS Pies for Christmas Pork Valentines BBQ Selection Burgers & Sausages Dairy & Cooked Meats FROZEN FOODS Bread Finger foods Chicken (frozen) Desserts & Ice Cream Frozen Chips & Potatoes Frozen Fish Frozen Fruit and Vegetables Ice Gift Vouchers Stir Frys Meat Packs Beef Galloways Beef Steaks Beef Sausages and Beef Burgers Slow Cook Butchers Beef Cuts Beef Roasting Joints Pies Chicken Chicken Fillets and Whole Chickens Oven Ready Chicken Dishes Chicken Burgers and Chicken Sausages Lamb Pork Pork Casseroles & Stir Frys Roasting Joints & Chops Pork Sausages & Burgers Gammon & Bacon Sausages Burgers & Patties Haggis & Puddings Bakery
# Products
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "Basket_Protocol",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "Session",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Cookies essential for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation)."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Basket_Protocol",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "Session",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Cookies essential for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation)."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Cookie",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Basket",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["Null"],
#         "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "cookie_name",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Null"
#     }
# ]
# ******************** Question:
# Content: None
# Answer:
# []
# Response:
# [
#   {
#     "cookie_name": "None",
#     "declared_purpose": "None",
#     "declared_retention": "None",
#     "declared_third_parties": ["None"],
#     "declared_description": "None"
#   }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#   {
#     "cookie_name": "None",
#     "declared_purpose": "None",
#     "declared_retention": "None",
#     "declared_third_parties": ["None"],
#     "declared_description": "None"
#   }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  []
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "",
#         "declared_purpose": "",
#         "declared_retention": "",
#         "declared_third_parties": ["First Party"],
#         "declared_description": ""
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#   {
#     "cookie_name": "",
#     "declared_purpose": "",
#     "declared_retention": "",
#     "declared_third_parties": [
#       "First Party"
#     ],
#     "declared_description": ""
#   }
# ]
# ******************** Question:
# Cookie policy: Home |Cookie settings
# This website uses cookies, which are necessary for the technical operation of the website and are always set. Other cookies that increase the comfort of using this website, serve direct advertising or simplify interaction with other websites and social networks will only be set with your consent.
# Fritz-Hintermay-Str. 1, D-86159 Augsburg
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "Necessary",
#       "declared_purpose": "Cookies essential for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation).",
#       "declared_retention": "Always set",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This website uses cookies, which are necessary for the technical operation of the website and are always set."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Necessary",
#       "declared_purpose": "Cookies essential for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation).",
#       "declared_retention": "Always set",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This website uses cookies, which are necessary for the technical operation of the website and are always set."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["N/A"],
#       "declared_description": "These cookies are necessary for the technical operation of the website and are always set."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Necessary cookies",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Cookies necessary for the technical operation of the website and are always set."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Necessary",
#       "declared_purpose": "Strictly Necessary for the website to function correctly with basic features (e.g., managing login sessions, shopping cart functionality, secure navigation).",
#       "declared_retention": "These cookies are always set.",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This website uses cookies, which are necessary for the technical operation of the website and are always set."
#     }
# ]
# ******************** Question:
# Cookie policy: How we use Cookies on our store
# Please read this cookie policy (“cookie policy”, "policy") carefully before using this website (“website”, "service").
# What are cookies?
# Cookies are simple text files that are stored on your computer or mobile device by a website’s server. Each cookie is unique to your web browser. It will contain some anonymous information such as a unique identifier, the website's domain name, and some digits and numbers.
# What types of cookies do we use?
# Necessary cookies
# Necessary cookies allow us to offer you the best possible experience when accessing and navigating through our website and using its features. For example, these cookies let us recognize that you have created an account and have logged into that account.
# Functionality cookies
# Functionality cookies let us operate the site in accordance with the choices you make. For example, we will recognize your username and remember how you customized the site during future visits.
# Analytical cookies
# These cookies enable us and third-party services to collect aggregated data for statistical purposes on how our visitors use the website. These cookies do not contain personal information such as names and email addresses and are used to help us improve your user experience of the website.
# How to delete cookies?
# If you want to restrict or block the cookies that are set by our website, you can do so through your browser setting. Alternatively, you can visit www.internetcookies.com, which contains comprehensive information on how to do this on a wide variety of browsers and devices. You will find general information about cookies and details on how to delete cookies from your device.
# Contacting us
# If you have any questions about this policy or our use of cookies, please contact us.
# Footer
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Necessary cookies allow us to offer you the best possible experience when accessing and navigating through our website and using its features. For example, these cookies let us recognize that you have created an account and have logged into that account.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["N/A"],
#       "declared_description": "N/A"
#     },
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Functionality cookies let us operate the site in accordance with the choices you make. For example, we will recognize your username and remember how you customized the site during future visits.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["N/A"],
#       "declared_description": "N/A"
#     },
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Analytical cookies enable us and third-party services to collect aggregated data for statistical purposes on how our visitors use the website. These cookies do not contain personal information such as names and email addresses and are used to help us improve your user experience of
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Necessary cookies allow us to offer you the best possible experience when accessing and navigating through our website and using its features. For example, these cookies let us recognize that you have created an account and have logged into that account.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["N/A"],
#       "declared_description": "N/A"
#     },
#     {
#       "cookie_name": "N/A",
#       "declared_purpose": "Functionality cookies let us operate the site in accordance with the choices you make. For example, we will recognize your username and remember how you customized the site during future visits.",
#       "declared_retention": "N/A",
#       "declared_third_parties": ["N/A"],
#       "declared_description": "N/A"
#     },
# ...
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "CS/PK Size: 12/12, Default UM is PK"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "CS/PK Size",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "CS/PK Size: 12/12, Default UM is PK\n\n7.20 lbs"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "CS/PK Size",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "CS/PK Size: 12/12, Default UM is PK"
#     }
# ]
# ******************** Question:
# Cookie policy: Concerts The Raveonettes return to Greece for two shows full of distortion, melody and nostalgia!
# Table: []
# Answer:
# []
# Response:
# [
#     {
#         "cookie_name": "UNDEF",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["UNDEF"],
#         "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "UNDEF",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["UNDEF"],
#         "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "N/A",
#         "declared_purpose": "N/A",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["N/A"],
#         "declared_description": "N/A"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "cookie_concertholder",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "The cookie policy does not provide any specific information about cookies used on the website."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "cookie_name",
#       "declared_purpose": "Null",
#       "declared_retention": "Null",
#       "declared_third_parties": ["Null"],
#       "declared_description": "Null"
#     }
# ]
# ******************** Question:
# Cookie policy: Sort by:
# Crackers & Cookies
# Everyone loves a cookie or tasty cracker! Enjoy a selection of these amazing tasty and unique cookies/snacks. They make the perfect gift or treat for yourself. For those gluten-free/vegan friends check out Peacasa Chips!
# Be a part of The Local Boom!
# Established in 2017 and as the first platform to bring you Canadian brands from around the country, we have thousands of customers across our amazing landscape and I hope you become one too!
# Quick links
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#         "cookie_name": "Cookies (Crackers & Cookies)",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "The Local Boom uses cookies to understand user behavior and improve the technical performance of the website, such as optimizing page loading, content distribution."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Cookies (Crackers & Cookies)",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "The Local Boom uses cookies to understand user behavior and improve the technical performance of the website, such as optimizing page loading, content distribution."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "SessionID",
#         "declared_purpose": "Null",
#         "declared_retention": "Session",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "This is a session cookie."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "session_id",
#       "declared_purpose": "Null",
#       "declared_retention": "Session",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "A session cookie. It could be retrieved by accessing the site."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "session_id",
#       "declared_purpose": "Strictly Necessary",
#       "declared_retention": "Session",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This cookie is used to maintain user session during browsing."
#     }
# ]
# ******************** Question:
# Cookie policy: Impreme S.p.A. - Via Ugo Ojetti, 504 - 00137 Rome (RM) - Tel: 06 87.13.25.54 - VAT number: 01100661006 - REA: RM - 413636
# This site is protected by reCAPTCHA, applying its Privacy Policy and its Terms of Service.
# Edit points:
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "reCAPTCHA",
#       "declared_purpose": "Analytical",
#       "declared_retention": "Unknown (reCAPTCHA doesn't specify retention)",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This site is protected by reCAPTCHA, applying its Privacy Policy and its Terms of Service."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "reCAPTCHA",
#       "declared_purpose": "Analytical",
#       "declared_retention": "Unknown (reCAPTCHA doesn't specify retention)",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "This site is protected by reCAPTCHA, applying its Privacy Policy and its Terms of Service."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Remembering user language preferences",
#       "declared_purpose": "Functionality",
#       "declared_retention": "Session",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "The cookie is used to remember user language preferences to enhance the user experience."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "reCAPTCHA",
#         "declared_purpose": "Targeting/Advertising/Marketing",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "This site is protected by reCAPTCHA, applying its Privacy Policy and its Terms of Service."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "reCAPTCHA",
#       "declared_purpose": "Analytical",
#       "declared_retention": "Not specified",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Table: []"
#     }
# ]
# ******************** Question:
# Cookie policy: discounted: 50 CZK /children, students, seniors from 65 years old/
# family: 270 CZK
# free: /children under 6 years old, children from DD, ZTP, ZTPP, AMG, ITIC/
# Increased entrance fee for ethnographic programs. More
# news
# Easter ethnographic programs were held in the museum
# On the 19th and 20th of April, traditional ethnographic programs White Saturday and Holy Easter were held in the Museum of Folk Buildings with great interest and public participation.
# (22/04/2025)
# more
# Exhibition "Cologne in the Shadow of the Death's Head"
# We invite you to the Regional Museum in Cologne for the exhibition, which takes place from April 30 to November 17.
# (22/04/2025)
# more
# Good Friday at the Museum of Folk Buildings
# On Good Friday, April 18, in our museum, in addition to a tour of the exhibits with an Easter installation, you can try making common objects.
# (12/04/2025)
# more
# In the museum, we recalled the customs of Deadly Sunday
# On Sunday, April 6, our first spring ethnographic program was held in the Museum of Folk Buildings in unseasonably cold weather.
# (8/4/2025)
#
# Table: [{'table_metadata': {'columns': ['Friday - Sunday:10.00 - 16.00More', ''], 'row_count': 1}, 'data': [{'Friday - Sunday:10.00 - 16.00More': 'Friday - Sunday:10.00 - 16.00More', '': ''}]}, {'table_metadata': {'columns': ['Regional Museum in Cologne| Karlovo náměstí 8, 280 02 Kolín I', 'contribution organization\r\n Central Bohemian Region', ''], 'row_count': 1}, 'data': [{'Regional Museum in Kolín| Karlovo náměstí 8, 280 02 Kolín I': 'Regional Museum in Kolín| Karlovo náměstí 8, 280 02 Kolín I', 'contributory organization of the Central Bohemian Region': 'contributory organization of the Central Bohemian Region', '': ''}]}]
# Answer:
# []
# Response:
# [
#     {
#       "cookie_name": "None",
#       "declared_purpose": "None",
#       "declared_retention": "None",
#       "declared_third_parties": ["None"],
#       "declared_description": "None"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "None",
#       "declared_purpose": "None",
#       "declared_retention": "None",
#       "declared_third_parties": ["None"],
#       "declared_description": "None"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "unnamed_cookie",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["Null"],
#         "declared_description": "Null"
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": null,
#       "declared_purpose": null,
#       "declared_retention": null,
#       "declared_third_parties": ["First Party"],
#       "declared_description": null
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "discounted",
#         "declared_purpose": "Null",
#         "declared_retention": "Null",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "50 CZK for /children, students, seniors from 65 years old/ "
#     }
# ]
# ******************** Question:
# Cookie policy: Cookie Policy (EU)
# Cookie Policy (EU)
# This Cookie Policy was last updated on July 15, 2024 and applies to citizens and legal residents of the European Economic Area and Switzerland.
# 1. Introduction
# Our website, moonstyle.sk (hereinafter referred to as the "website") uses cookies and other related technologies (all technologies are referred to as "cookies" for convenience). Cookies are also placed by third parties that we have engaged. In the document below, we inform you about the use of cookies on our website.
# 2. What are cookies?
# A cookie is a small simple file that is sent together with the pages of this website and stored by your browser on the hard drive of your computer or other device. The information stored in them may be returned to our servers or to the servers of the relevant third parties during the next visit.
# 3. What are scripts?
# A script is a piece of programming code that is used to make our website function properly and interactively. This code will run on our server or your device.
# 4. What is a web beacon?
# A web beacon (or pixel tag) is a small invisible text or image on a website that is used to monitor website traffic. For this purpose, various data about you are stored using web beacons.
# 5. Cookies
# 5.1 Technical or functional cookies
# Some cookies ensure that certain parts of the website work properly and that your user preferences remain known. By placing functional cookies, we make it easier for you to visit our website. This way you don't have to enter the same information repeatedly when you visit our website, and for example the items will stay in your shopping cart until you pay. We may place these cookies without your consent.
# 5.2 Marketing/tracking cookies
# Marketing/tracking cookies are cookies or any other form of local storage that are used to create profiles of users to display advertising or to track a user on this website or several websites for similar marketing purposes.
# 5.3 Social Media
# We have included content from Instagram on our website to promote the website (e.g. "liking", "pinning") or sharing (e.g. "tweeting") on social networks such as Instagram. This content is embedded with code derived from Instagram and places cookies. This content may store and process certain information for the purpose of personalized advertising.
# Please read the privacy statement of these social networks (which may change periodically) and read what they do with your (personal) data that they process using these cookies. The data obtained are anonymized as much as possible. Instagram is located in the US.
# 6. Placed cookies
#
# Table: []
# Answer:
# []
# Response:
# [
#     {
#         "cookie_name": "Functional cookies",
#         "declared_purpose": "Some cookies ensure that certain parts of the website work properly and that your user preferences remain known. By placing functional cookies, we make it easier for you to visit our website. This way you don't have to enter the same information repeatedly when you visit our website, and for example the items will stay in your shopping cart until you pay. We may place these cookies without your consent.",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "Functional cookies make it easier to navigate the website and store user preferences."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "Functional cookies",
#         "declared_purpose": "Some cookies ensure that certain parts of the website work properly and that your user preferences remain known. By placing functional cookies, we make it easier for you to visit our website. This way you don't have to enter the same information repeatedly when you visit our website, and for example the items will stay in your shopping cart until you pay. We may place these cookies without your consent.",
#         "declared_retention": "N/A",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "Functional cookies make it easier to navigate the website and store user preferences."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#         "cookie_name": "technical or functional cookies",
#         "declared_purpose": "To ensure that certain parts of the website work properly and to keep user preferences known, making it easier for you to visit our website.",
#         "declared_retention": "Not specified",
#         "declared_third_parties": ["First Party"],
#         "declared_description": "These cookies ensure that the website works properly and keep user preferences known. They are used to make it easier for you to visit our website. We may place these cookies without your consent."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Functional cookies",
#       "declared_purpose": "To ensure that certain parts of the website work properly and that your user preferences remain known",
#       "declared_retention": "Not specified",
#       "declared_third_parties": ["First Party"],
#       "declared_description": "Cookies are placed to make it easier for you to visit our website. This way you don't have to enter the same information repeatedly when you visit our website, and for example the items will stay in your shopping cart until you pay."
#     }
# ]
# Len of comp:  1
# Answer:  []
# ---> PREDICT:  [
#     {
#       "cookie_name": "Functional cookies",
#       "declared_purpose": "These cookies ensure that certain parts of the website work properly and that your user preferences remain known. By placing functional cookies, we make it easier for you to visit our website. This way you don't have to enter the same information repeatedly when you visit our website, and for example the items will stay in your shopping cart until you pay.",
#       "declared_retention": "N/A (No specific retention period is declared)",
#       "declared_third_parties": ["N/A (Not a third-party cookie)"],
#       "declared_description": "These cookies are set by the website and have no specific retention period mentioned. They are used to ensure the proper functioning of certain parts of the website and to maintain user preferences."
#     }
# ]
# TrainOutput(global_step=300, training_loss=0.001978319519564818, metrics={'train_runtime': 11383.564, 'train_samples_per_second': 0.211, 'train_steps_per_second': 0.026, 'total_flos': 0.0, 'train_loss': 0.001978319519564818})

# %%
# new_model = "/content/drive/MyDrive/model/Qwen2.5_(3B)_GRPO-detect-cookie"
new_model_to_hub = "sonhask/Qwen2_5_3B_GRPO_detect_cookie"

# model.save_pretrained_merged(new_model, tokenizer)
model.push_to_hub_merged(new_model_to_hub, tokenizer)
# Out:
# Unsloth: You are pushing to hub, but you passed your HF username = sonhask.
# We shall truncate sonhask/Qwen2_5_3B_GRPO_detect_cookie to Qwen2_5_3B_GRPO_detect_cookie
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 0.0 out of 12.67 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
# 100%|██████████| 36/36 [11:30<00:00, 19.17s/it]
# Unsloth: Saving tokenizer...
#   0%|          | 0/1 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
#  Done.
# Unsloth: Saving Qwen2_5_3B_GRPO_detect_cookie/pytorch_model-00001-of-00002.bin...
# Unsloth: Saving Qwen2_5_3B_GRPO_detect_cookie/pytorch_model-00002-of-00002.bin...
# README.md:   0%|          | 0.00/608 [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/1.21G [00:00<?, ?B/s]

# %%
wandb.finish()
model.config.use_cache = True

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s, est. speed input: 63.38 toks/s, output: 25.69 toks/s]
# 'There are 2 r\'s in the word "strawberry."'

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "How many r's are in strawberry?"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it, est. speed input: 14.05 toks/s, output: 29.09 toks/s]
# '<reasoning>\nTo find out how many times the letter \'r\' appears in the word "strawberry", we can go through the word character by character and count each occurrence of \'r\'. In "strawberry", the letter \'r\' appears 3 times: once in the beginning, once in the middle, and once at the end of the word.\n</reasoning>\n<answer>\n3\n</answer>'

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "",
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
